# %%
# read neccessary libraries
import numpy as np
import pandas as pd
import requests
import re
from bs4 import BeautifulSoup

pd.options.display.max_rows = 20

np.set_printoptions(precision = 4, suppress = True)

# %%
def get_team_name(soup):
    title = soup.find('title')
    pattern = '<title>(.*) Statistics | Premier League</title>'
    regex = re.compile(pattern, flags=re.IGNORECASE)
    team_name = regex.match(str(title)).groups()[0]
    return team_name

# Return the filtered club name for the given index 
def get_premier_teams(target_teams, i):
    pattern = '<h4 class="clubName">(.*)<'
    regex = re.compile(pattern, flags=re.IGNORECASE)
    result = regex.match(str(target_teams[i])).groups()
    return result[0]

# %%
# Get the 20 Premier League teams (first division)

premier_teams = []
url = "https://www.premierleague.com/clubs?se=210"
res = requests.get(url)
soup = BeautifulSoup(res.content)
target_teams = soup.find_all('h4', attrs={'clubName'})

for i in range(0,20):
    premier_teams.append(get_premier_teams(target_teams, i))

premier_teams
# Out:
# ['Arsenal',
#  'Aston Villa',
#  'AFC Bournemouth',
#  'Brighton and Hove Albion',
#  'Burnley',
#  'Chelsea',
#  'Crystal Palace',
#  'Everton',
#  'Leicester City',
#  'Liverpool',
#  'Manchester City',
#  'Manchester United',
#  'Newcastle United',
#  'Norwich City',
#  'Sheffield United',
#  'Southampton',
#  'Tottenham Hotspur',
#  'Watford',
#  'West Ham United',
#  'Wolverhampton Wanderers']

# %%
headers = ['Team']
team_stats = []
premier_teams_index = []

# Iterate through clubs using numbers 1-46 in the URL
# Since the 20 Premier League teams are found in mixed order with second division teams, we have to extract all
for team in range(1,2):
    url = "https://www.premierleague.com/clubs/" + str(team) + "/club/stats"  
    res = requests.get(url)                                                     
    soup = BeautifulSoup(res.content)
    
    team_name = get_team_name(soup)
    
    # Filter out FC from the football clubs' names
    if 'FC' in team_name:
        team_name = team_name[:-3]
        
    # Filter out teams that aren't in the Premier League
    if team_name not in premier_teams:
        continue
    
    # Append the indices (for URL) of the Premier League teams (first division)
    premier_teams_index.append(team)
    
    # Find all match stats
    match_stats = soup.find_all('div', attrs={'topStat'})
    
    # Find all the stats that are enclosed in 'div' classed as normalStat
    all_stats = soup.find_all('div', attrs={'normalStat'})                     

    stats = [team_name]
    
    for i in range(0,1): 
        
        
        match_span = match_stats[i].findChildren()[0]
        print(match_span)
        
        # Filter the first child from each 'div' tag which contains the stat name
        span = all_stats[i].findChildren()[0]
        print(span)
        
        
        # Only need to extract headers once
        if team == 1:
            pattern = '<span class="stat">(.*)<'
            regex = re.compile(pattern, flags=re.IGNORECASE)
            
            match_result = regex.match(str(match_span)).group()
            print(match_result)
            
            result = regex.match(str(span)).groups()
            print(result)
            
            headers.append(result[0].strip())
            
        
        # Extract the statistical data
        pattern = '(.*)\\n( *)(.*)'
        regex = re.compile(pattern, flags=re.IGNORECASE)
        result = regex.match(str(span)).groups()
                
        value = result[2].replace(',', '').replace('%', '')
    
        # Use float for appropriate values
        if (value.isdigit()):
            data_value = int(value.replace(',','').replace('%','')) 
        else:
            data_value = float(value.replace(',','').replace('%',''))
        stats.append(data_value)
        
    team_stats.append(stats)
# Out:
# <span class="stat">Matches played   <span class="allStatContainer statmatches_played" data-stat="wins,draws,losses">
#       1,062
# ('Goals   ',)

# %%
pd.DataFrame(team_stats, columns=headers).set_index('Team')
# Out:
#                          Goals  Goals per match  Shots  Shots on target  \
# Team
# Arsenal                   1877             1.77   8072             2916
# Aston Villa               1148             1.21   4861             1572
# Chelsea                   1811             1.71   8889             3006
# Crystal Palace             447             1.08   2956              946
# Everton                   1385             1.30   6976             2366
# Liverpool                 1826             1.72   8790             2968
# Manchester City           1439             1.65   8336             2930
# Manchester United         2025             1.91   8059             2886
# Norwich City               388             1.14   2081              668
# Sheffield United           153             1.05    720              223
# Southampton                968             1.22   3861             1278
# Tottenham Hotspur         1583             1.49   8223             2825
# Newcastle United          1273             1.35   5480             1757
# West Ham United           1090             1.21   6107             1964
# Leicester City             671             1.29   2668              919
# Watford                    261             1.03   2446              781
# Wolverhampton Wanderers    237             1.11   2133              659
# Burnley                    216             1.01   2246              718
#
#                          Shooting accuracy %  Penalties scored  \
# Team
# Arsenal                                   36                58
# Aston Villa                               32                37
# Chelsea                                   34                69
# Crystal Palace                            32                39
# Everton                                   34                49
# Liverpool                                 34                68
# Manchester City                           35                71
# Manchester United                         36                66
# Norwich City                              32                 6
# Sheffield United                          31                 3
# Southampton                               33                22
# Tottenham Hotspur                         34                52
# Newcastle United                          32                31
# West Ham United                           32                39
# Leicester City                            34                30
# Watford                                   32                20
# Wolverhampton Wanderers                   31                15
# Burnley                                   32                16
#
#                          Big chances created  Hit woodwork  Passes  \
# Team
# Arsenal                                  716           221  278479
# Aston Villa                              272           109  146971
# Chelsea                                  591           199  268239
# Crystal Palace                           259            69   89917
# Everton                                  511           164  213623
# Liverpool                                637           253  267918
# Manchester City                          772           216  275683
# Manchester United                        618           203  264991
# Norwich City                             178            50   68490
# Sheffield United                          44            17   20523
# Southampton                              369           109  129617
# Tottenham Hotspur                        573           185  245129
# Newcastle United                         380           133  167478
# West Ham United                          361           163  179299
# Leicester City                           320            55   84914
# Watford                                  194            49   79048
# Wolverhampton Wanderers                  169            52   69480
# Burnley                                  166            57   73920
#
#                          Passes per match  ...  Saves  Tackles  \
# Team                                       ...
# Arsenal                            262.22  ...    793    10307
# Aston Villa                        154.87  ...    425     8515
# Chelsea                            252.58  ...    602    10229
# Crystal Palace                     218.25  ...    758     4819
# Everton                            201.15  ...    707     9960
# Liverpool                          252.51  ...    547    11194
# Manchester City                    316.15  ...    510    10142
